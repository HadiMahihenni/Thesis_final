# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Datasets/Snopes/New_1.csv')
df.head()
# Out:
#    doc_id          author                                              title  \
# 0       1  BETHANIA PALMA  Donald Trump Called President Obama a ‘Lying N...
# 1       2        DAN EVON                  What If Only Taxpayers Voted?\n\n
# 2       3        DAN EVON  Empire State Building Lit Green on 9/11 for Mu...
# 3       4     DAVID EMERY  Did Obama Call Americans ‘Lazy’ in an Overseas...
# 4       5        DAN EVON           Ivanka Trump’s ‘Lap Dance’ with Donald\n
#
#                                             mainText  \
# 0  It is hardly a secret that Republican presiden...
# 1  On 28 August 2016, the web site The Burning Pl...
# 2  In September 2016, several online articles (in...
# 3  Barack Obama became the first sitting United S...
# 4  In September 2016, a photograph purportedly sh...
#
#                     veracity        date
# 0                      FALSE  2016-09-01
# 1                      FALSE  2016-09-01
# 2                      FALSE  2016-09-06
# ...

# %%
len(df)
# Out:
# 75

# %% [markdown]
# # Covert Label

# %%
df['veracity']=df['veracity'].replace(['Mixture of True and False','Mostly False','FALSE',], 'False')
df['veracity']=df['veracity'].replace(['mostly true','TRUE'], 'True')

# %%
df
# Out:
#     doc_id            author  \
# 0        1    BETHANIA PALMA
# 1        2          DAN EVON
# 2        3          DAN EVON
# 3        4       DAVID EMERY
# 4        5          DAN EVON
# 5        6          DAN EVON
# 6        7          DAN EVON
# 7        8    BETHANIA PALMA
# 8        9      KIM LACAPRIA
# 9       10          DAN EVON
# 10      11          DAN EVON
# 11      12      KIM LACAPRIA
# 12      13       DAVID EMERY
# 13      14    BETHANIA PALMA
# 14      15          DAN EVON
# 15      16          DAN EVON
# 16      17       DAVID EMERY
# 17      18      KIM LACAPRIA
# 18      19       DAVID EMERY
# 19      20       DAVID EMERY
# 20      21          DAN EVON
# 21      22       DAVID EMERY
# 22      23       DAVID EMERY
# 23      24    BETHANIA PALMA
# 24      25          DAN EVON
# 25      26          DAN EVON
# 26      27       DAVID EMERY
# 27      28          DAN EVON
# 28      29      KIM LACAPRIA
# 29      30          DAN EVON
# ..     ...               ...
# ...

# %%
df.to_csv("NEW_1.csv",index=False)
